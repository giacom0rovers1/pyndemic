# %%
#%matplotlib inline  # sembra non essere necessario.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # prova
# ## prova
#
# *ciao* **ciao** test TEST

# %%
x = np.linspace(-10, 10, 1000)
y = np.sin(x)
plt.plot(x,y);
